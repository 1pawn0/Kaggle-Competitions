# %%
# %conda install -y -c conda-forge \
python-lsp-server \
jupyter-resource-usage \
jupyter-lsp-python \
jupyter-lsp-python-plugins \
jupyter-lsp

# %%
# %conda install -y -c conda-forge \
jupyterlab-lsp \
jupyterthemes \
jupyter-themer \
jupyterlab-git \
jupyterlab-variableinspector \
jupyterlab-cell-flash
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ali/Public/Apps/anaconda3/envs/tf-env-0019
#
#   added / updated specs:
#     - jupyter-themer
#     - jupyterlab-cell-flash
#     - jupyterlab-git
#     - jupyterlab-lsp
#     - jupyterlab-variableinspector
#     - jupyterthemes
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyterlab-cell-flash-0.4.0|     pyhd8ed1ab_1          20 KB  conda-forge
#     jupyterthemes-0.20.0       |     pyhd8ed1ab_2         4.7 MB  conda-forge
#     lesscpy-0.15.1             |     pyhd8ed1ab_1          41 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   gitdb              conda-forge/noarch::gitdb-4.0.12-pyhd8ed1ab_0
#   gitpython          conda-forge/noarch::gitpython-3.1.44-pyhff2d567_0
#   jupyter-server-ma~ conda-forge/noarch::jupyter-server-mathjax-0.2.6-pyhbbac1ac_2
#   jupyter-themer     conda-forge/noarch::jupyter-themer-0.4.0-pyhd8ed1ab_2
#   jupyterlab-cell-f~ conda-forge/noarch::jupyterlab-cell-flash-0.4.0-pyhd8ed1ab_1
#   jupyterlab-git     conda-forge/noarch::jupyterlab-git-0.50.2-pyhd8ed1ab_1
#   jupyterlab-lsp     conda-forge/noarch::jupyterlab-lsp-5.1.0-pyhd8ed1ab_3
#   jupyterlab-variab~ conda-forge/noarch::jupyterlab-variableinspector-3.2.4-pyhd8ed1ab_0
#   jupyterthemes      conda-forge/noarch::jupyterthemes-0.20.0-pyhd8ed1ab_2
#   lesscpy            conda-forge/noarch::lesscpy-0.15.1-pyhd8ed1ab_1
#   nbdime             conda-forge/noarch::nbdime-4.0.2-pyhd8ed1ab_1
#   smmap              conda-forge/noarch::smmap-5.0.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# jupyterthemes-0.20.0 | 4.7 MB    |                                       |   0%
# lesscpy-0.15.1       | 41 KB     |                                       |   0%
#
# jupyterlab-cell-flas | 20 KB     |                                       |   0%
# jupyterthemes-0.20.0 | 4.7 MB    | 1                                     |   0%
# lesscpy-0.15.1       | 41 KB     | ##################################### | 100%
# lesscpy-0.15.1       | 41 KB     | ##################################### | 100%
#
# jupyterlab-cell-flas | 20 KB     | #############################5        |  80%
#
# jupyterthemes-0.20.0 | 4.7 MB    | 4                                     |   1%
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda install -y -c conda-forge \
jupyterlab-spellchecker \
jupyterlab-github \
jupyterlab-fonts \
jupyterlab-night

# jupyterlab-topbar \
# jupyterlab-h5web \
# jupyterlab-spreadsheet-editor \
# jupyterlab-system-monitor \
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ali/Public/Apps/anaconda3/envs/tf-env-0019
#
#   added / updated specs:
#     - jupyterlab-fonts
#     - jupyterlab-github
#     - jupyterlab-night
#     - jupyterlab-spellchecker
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyterlab-fonts-3.0.0     |     pyh885dcc9_1         961 KB  conda-forge
#     jupyterlab-github-4.0.0    |     pyhd8ed1ab_3          29 KB  conda-forge
#     jupyterlab-night-0.4.6     |     pyhd8ed1ab_1          81 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   jupyterlab-fonts   conda-forge/noarch::jupyterlab-fonts-3.0.0-pyh885dcc9_1
#   jupyterlab-github  conda-forge/noarch::jupyterlab-github-4.0.0-pyhd8ed1ab_3
#   jupyterlab-night   conda-forge/noarch::jupyterlab-night-0.4.6-pyhd8ed1ab_1
#   jupyterlab-spellc~ conda-forge/noarch::jupyterlab-spellchecker-0.8.4-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# jupyterlab-fonts-3.0 | 961 KB    |                                       |   0%
# jupyterlab-night-0.4 | 81 KB     |                                       |   0%
#
# jupyterlab-github-4. | 29 KB     |                                       |   0%
# jupyterlab-night-0.4 | 81 KB     | #######3                              |  20%
#
# jupyterlab-github-4. | 29 KB     | ####################                  |  54%
#
# jupyterlab-github-4. | 29 KB     | ##################################### | 100%
#
# jupyterlab-fonts-3.0 | 961 KB    | 6                                     |   2%
# jupyterlab-night-0.4 | 81 KB     | #############################2        |  79%
# jupyterlab-night-0.4 | 81 KB     | ##################################### | 100%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
